# %% [markdown]
# # 🚀 AntiGravity Crypto Hunter - Demo Interactiva
#
# Ejecuta la celda de abajo para instalar y arrancar el bot de arbitraje directamente en Google Colab. **No necesitas configurar nada**.

# %%
# !git clone https://github.com/nicco6482/Bot-de-Arbitraje-Cripto.git
# %cd Bot-de-Arbitraje-Cripto
# !pip install -r requirements.txt
# !python monitor.py
